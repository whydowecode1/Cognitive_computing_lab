# %%
# !unzip "*.zip"
# Out:
# Archive:  archive.zip
#   inflating: AWCustomers.csv
#   inflating: AWSales.csv
#   inflating: AWTest-Classification.csv
#   inflating: AWTest-Regression.csv

# %%
import pandas as pd

customers = pd.read_csv("AWCustomers.csv")

customers.head()
# Out:
#    CustomerID Title FirstName MiddleName  LastName Suffix  \
# 0       21173   NaN      Chad          C      Yuan    NaN
# 1       13249   NaN      Ryan        NaN     Perry    NaN
# 2       29350   NaN     Julia        NaN  Thompson    NaN
# 3       13503   NaN  Theodore        NaN     Gomez    NaN
# 4       22803   NaN  Marshall          J      Shan    NaN
#
#              AddressLine1 AddressLine2         City    StateProvinceName  ...  \
# 0      7090 C. Mount Hood          NaN   Wollongong      New South Wales  ...
# 1     3651 Willow Lake Rd          NaN      Shawnee     British Columbia  ...
# 2  1774 Tice Valley Blvd.          NaN  West Covina           California  ...
# 3         2103 Baldwin Dr          NaN    Liverpool              England  ...
# 4         Am Gallberg 234          NaN        Werne  Nordrhein-Westfalen  ...
#
#          Education      Occupation Gender MaritalStatus HomeOwnerFlag  \
# 0        Bachelors        Clerical      M             M             1
# ...

# %%
classification = pd.read_csv("AWTest-Classification.csv")

classification.head()
# Out:
#    CustomerID  Title FirstName MiddleName   LastName  Suffix  \
# 0       11219    NaN   Charles        NaN       Cook     NaN
# 1       11241    NaN      Lisa        NaN        Cai     NaN
# 2       11352    NaN   Raymond          A  Rodriguez     NaN
# 3       11904    NaN    Kaylee        NaN       Cook     NaN
# 4       11908    NaN    Rafael          A       Tang     NaN
#
#                 AddressLine1  AddressLine2             City  \
# 0           6871 Bel Air Dr.           NaN         Woodburn
# 1          102, rue de Berri           NaN         Les Ulis
# 2  24, impasse Ste-Madeleine           NaN           Pantin
# 3          5742 Curtis Drive           NaN          Geelong
# 4            8839 Leonard Dr           NaN  South Melbourne
#
#    StateProvinceName  ...        Education      Occupation Gender  \
# 0             Oregon  ...      High School  Skilled Manual      M
# 1            Essonne  ...  Partial College  Skilled Manual      F
# ...

# %%
sales = pd.read_csv("AWSales.csv")

sales.head()
# Out:
#    CustomerID  BikeBuyer  AvgMonthSpend
# 0       21173          1          50.97
# 1       13249          1          53.11
# 2       29350          1          54.08
# 3       13503          1          56.93
# 4       22803          1          55.41

# %%
regression = pd.read_csv("AWTest-Regression.csv")

regression.head()
# Out:
#    CustomerID  Title FirstName MiddleName  LastName  Suffix  \
# 0       11908    NaN    Rafael          A      Tang     NaN
# 1       12286    NaN    Nathan          M   Jenkins     NaN
# 2       12892    NaN     Brian        NaN  Peterson     NaN
# 3       14698    NaN     Diane        NaN   Navarro     NaN
# 4       15085    NaN   Kristin          H       Jai     NaN
#
#              AddressLine1  AddressLine2               City StateProvinceName  \
# 0         8839 Leonard Dr           NaN    South Melbourne          Victoria
# 1       3093 Roland Drive           NaN       Peterborough           England
# 2          1284 Poppy Pl.           NaN          Royal Oak  British Columbia
# 3  Potsdamer Straße 92324           NaN  Frankfurt am Main          Saarland
# 4  88, impasse Notre-Dame           NaN           Morangis           Essonne
#
#    ...        Education    Occupation Gender MaritalStatus HomeOwnerFlag  \
# ...

# %% [markdown]
# To perform important data manipulation and analysis operations using NumPy and Pandas on the Microsoft Adventure Works customer dataset.

# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv("AWCustomers.csv")

# %%
df.head()
# Out:
#    CustomerID Title FirstName MiddleName  LastName Suffix  \
# 0       21173   NaN      Chad          C      Yuan    NaN
# 1       13249   NaN      Ryan        NaN     Perry    NaN
# 2       29350   NaN     Julia        NaN  Thompson    NaN
# 3       13503   NaN  Theodore        NaN     Gomez    NaN
# 4       22803   NaN  Marshall          J      Shan    NaN
#
#              AddressLine1 AddressLine2         City    StateProvinceName  ...  \
# 0      7090 C. Mount Hood          NaN   Wollongong      New South Wales  ...
# 1     3651 Willow Lake Rd          NaN      Shawnee     British Columbia  ...
# 2  1774 Tice Valley Blvd.          NaN  West Covina           California  ...
# 3         2103 Baldwin Dr          NaN    Liverpool              England  ...
# 4         Am Gallberg 234          NaN        Werne  Nordrhein-Westfalen  ...
#
#          Education      Occupation Gender MaritalStatus HomeOwnerFlag  \
# 0        Bachelors        Clerical      M             M             1
# ...

# %%
df.shape
# Out:
# (18361, 24)

# %%
df.columns
# Out:
# Index(['CustomerID', 'Title', 'FirstName', 'MiddleName', 'LastName', 'Suffix',
#        'AddressLine1', 'AddressLine2', 'City', 'StateProvinceName',
#        'CountryRegionName', 'PostalCode', 'PhoneNumber', 'BirthDate',
#        'Education', 'Occupation', 'Gender', 'MaritalStatus', 'HomeOwnerFlag',
#        'NumberCarsOwned', 'NumberChildrenAtHome', 'TotalChildren',
#        'YearlyIncome', 'LastUpdated'],
#       dtype='object')

# %%
df.dtypes
# Out:
# CustomerID               int64
# Title                   object
# FirstName               object
# MiddleName              object
# LastName                object
# Suffix                  object
# AddressLine1            object
# AddressLine2            object
# City                    object
# StateProvinceName       object
# CountryRegionName       object
# PostalCode              object
# PhoneNumber             object
# BirthDate               object
# Education               object
# Occupation              object
# Gender                  object
# MaritalStatus           object
# HomeOwnerFlag            int64
# NumberCarsOwned          int64
# NumberChildrenAtHome     int64
# TotalChildren            int64
# YearlyIncome             int64
# LastUpdated             object
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18361 entries, 0 to 18360
# Data columns (total 24 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   CustomerID            18361 non-null  int64
#  1   Title                 101 non-null    object
#  2   FirstName             18361 non-null  object
#  3   MiddleName            10572 non-null  object
#  4   LastName              18361 non-null  object
#  5   Suffix                3 non-null      object
#  6   AddressLine1          18361 non-null  object
#  7   AddressLine2          311 non-null    object
#  8   City                  18361 non-null  object
#  9   StateProvinceName     18361 non-null  object
#  10  CountryRegionName     18361 non-null  object
#  11  PostalCode            18361 non-null  object
#  12  PhoneNumber           18361 non-null  object
#  13  BirthDate             18361 non-null  object
#  14  Education             18361 non-null  object
# ...

# %%
df.describe()
# Out:
#          CustomerID  HomeOwnerFlag  NumberCarsOwned  NumberChildrenAtHome  \
# count  18361.000000   18361.000000     18361.000000          18361.000000
# mean   20241.987092       0.610588         1.270301              0.338162
# std     5336.332731       0.487630         0.913989              0.568957
# min    11000.000000       0.000000         0.000000              0.000000
# 25%    15621.000000       0.000000         1.000000              0.000000
# 50%    20248.000000       1.000000         1.000000              0.000000
# 75%    24863.000000       1.000000         2.000000              1.000000
# max    29483.000000       1.000000         5.000000              3.000000
#
#        TotalChildren   YearlyIncome
# count   18361.000000   18361.000000
# mean        0.850389   72754.779642
# std         0.927315   30686.014313
# min         0.000000   25435.000000
# 25%         0.000000   53312.000000
# 50%         0.000000   61851.000000
# 75%         2.000000   87410.000000
# ...

# %%
df["FirstName"]
# Out:
# 0            Chad
# 1            Ryan
# 2           Julia
# 3        Theodore
# 4        Marshall
#            ...
# 18356       Grace
# 18357       Tasha
# 18358      Jaclyn
# 18359        Erin
# 18360      Amanda
# Name: FirstName, Length: 18361, dtype: object

# %%
df.iloc[0]
# Out:
# CustomerID                            21173
# Title                                   NaN
# FirstName                              Chad
# MiddleName                                C
# LastName                               Yuan
# Suffix                                  NaN
# AddressLine1             7090 C. Mount Hood
# AddressLine2                            NaN
# City                             Wollongong
# StateProvinceName           New South Wales
# CountryRegionName                 Australia
# PostalCode                             2500
# PhoneNumber             1 (11) 500 555-0115
# BirthDate                        1987-11-13
# Education                         Bachelors
# Occupation                         Clerical
# Gender                                    M
# MaritalStatus                             M
# HomeOwnerFlag                             1
# NumberCarsOwned                           3
# NumberChildrenAtHome                      0
# ...

# %%
df.iloc[0:5]
# Out:
#    CustomerID Title FirstName MiddleName  LastName Suffix  \
# 0       21173   NaN      Chad          C      Yuan    NaN
# 1       13249   NaN      Ryan        NaN     Perry    NaN
# 2       29350   NaN     Julia        NaN  Thompson    NaN
# 3       13503   NaN  Theodore        NaN     Gomez    NaN
# 4       22803   NaN  Marshall          J      Shan    NaN
#
#              AddressLine1 AddressLine2         City    StateProvinceName  ...  \
# 0      7090 C. Mount Hood          NaN   Wollongong      New South Wales  ...
# 1     3651 Willow Lake Rd          NaN      Shawnee     British Columbia  ...
# 2  1774 Tice Valley Blvd.          NaN  West Covina           California  ...
# 3         2103 Baldwin Dr          NaN    Liverpool              England  ...
# 4         Am Gallberg 234          NaN        Werne  Nordrhein-Westfalen  ...
#
#          Education      Occupation Gender MaritalStatus HomeOwnerFlag  \
# 0        Bachelors        Clerical      M             M             1
# ...

# %%
df.loc[0]
# Out:
# CustomerID                            21173
# Title                                   NaN
# FirstName                              Chad
# MiddleName                                C
# LastName                               Yuan
# Suffix                                  NaN
# AddressLine1             7090 C. Mount Hood
# AddressLine2                            NaN
# City                             Wollongong
# StateProvinceName           New South Wales
# CountryRegionName                 Australia
# PostalCode                             2500
# PhoneNumber             1 (11) 500 555-0115
# BirthDate                        1987-11-13
# Education                         Bachelors
# Occupation                         Clerical
# Gender                                    M
# MaritalStatus                             M
# HomeOwnerFlag                             1
# NumberCarsOwned                           3
# NumberChildrenAtHome                      0
# ...

# %%
df[df["Gender"] == "M"]
# Out:
#        CustomerID Title FirstName MiddleName   LastName Suffix  \
# 0           21173   NaN      Chad          C       Yuan    NaN
# 1           13249   NaN      Ryan        NaN      Perry    NaN
# 3           13503   NaN  Theodore        NaN      Gomez    NaN
# 4           22803   NaN  Marshall          J       Shan    NaN
# 6           11229   NaN    Adrian          C    Stewart    NaN
# ...           ...   ...       ...        ...        ...    ...
# 18343       29310   NaN   Armando        NaN  Gutierrez    NaN
# 18347       29064   NaN      Jose        NaN     Butler    NaN
# 18348       11287   NaN     Henry          B     Garcia    NaN
# 18349       11465   NaN     Louis        NaN        Luo    NaN
# 18355       14522   NaN      Omar          C      Zheng    NaN
#
#               AddressLine1 AddressLine2          City    StateProvinceName  \
# 0       7090 C. Mount Hood          NaN    Wollongong      New South Wales
# ...

# %%
df[df["YearlyIncome"] > 50000]
# Out:
#        CustomerID Title FirstName MiddleName  LastName Suffix  \
# 0           21173   NaN      Chad          C      Yuan    NaN
# 1           13249   NaN      Ryan        NaN     Perry    NaN
# 2           29350   NaN     Julia        NaN  Thompson    NaN
# 3           13503   NaN  Theodore        NaN     Gomez    NaN
# 4           22803   NaN  Marshall          J      Shan    NaN
# ...           ...   ...       ...        ...       ...    ...
# 18356       25414   NaN     Grace          C    Bailey    NaN
# 18357       11459   NaN     Tasha        NaN      Deng    NaN
# 18358       12160   NaN    Jaclyn        NaN     Zhang    NaN
# 18359       14353   NaN      Erin          I      Reed    NaN
# 18360       16676   NaN    Amanda        NaN     Perry    NaN
#
#                  AddressLine1 AddressLine2            City  \
# 0          7090 C. Mount Hood          NaN      Wollongong
# 1         3651 Willow Lake Rd          NaN         Shawnee
# ...

# %%
df.sort_values("YearlyIncome")
# Out:
#        CustomerID Title FirstName MiddleName   LastName Suffix  \
# 7539        25367   NaN   Abigail        NaN     Torres    NaN
# 2088        17096   NaN  Samantha          S    Bennett    NaN
# 4355        29302   NaN   Carolyn          S  Fernandez    NaN
# 6963        24613   NaN     Stacy        NaN    Serrano    NaN
# 17743       27337   NaN     Julia          R       Hall    NaN
# ...           ...   ...       ...        ...        ...    ...
# 10185       22052   NaN   Zachary        NaN     Butler    NaN
# 10577       13560   NaN    Andres          T       Shan    NaN
# 9525        20303   NaN     Bryce          J     Morgan    NaN
# 16892       17466   NaN    Thomas        NaN      Perez    NaN
# 10950       14645   NaN     Isaac          P      Kelly    NaN
#
#                AddressLine1 AddressLine2               City StateProvinceName  \
# 7539        682 Ambush Dr..          NaN            Shawnee  British Columbia
# ...

# %% [markdown]
# mathematical function

# %%
df["YearlyIncome"].mean()
# Out:
# np.float64(72754.77964163171)

# %%
df["YearlyIncome"].median()
# Out:
# 61851.0

# %%
df.groupby("Gender")["YearlyIncome"].mean()
# Out:
# Gender
# F    72765.783117
# M    72744.028535
# Name: YearlyIncome, dtype: float64

# %% [markdown]
# numpy

# %%
arr = np.array([10, 20, 30, 40, 50])

print(arr)
# Out:
# [10 20 30 40 50]

# %%
print(arr.ndim)
print(arr.shape)
print(arr.size)
print(arr.dtype)
# Out:
# 1
# (5,)
# 5
# int64

# %%
np.zeros(5)
# Out:
# array([0., 0., 0., 0., 0.])

# %%
arr[0]
# Out:
# np.int64(10)

# %%
arr[1:4]
# Out:
# array([20, 30, 40])

# %%
np.sort(arr)
# Out:
# array([10, 20, 30, 40, 50])

# %%
arr2 = np.array([10, 20, 20, 30, 30, 30, 40])

np.unique(arr2)
# Out:
# array([10, 20, 30, 40])

# %%
np.where(arr > 25, "High", "Low")
# Out:
# array(['Low', 'Low', 'High', 'High', 'High'], dtype='<U4')

# %%
print("Dataset Shape:", df.shape)
print("Number of Columns:", len(df.columns))
print("Number of Rows:", len(df))
print("Missing Values:", df.isnull().sum().sum())
# Out:
# Dataset Shape: (18361, 24)
# Number of Columns: 24
# Number of Rows: 18361
# Missing Values: 62457
